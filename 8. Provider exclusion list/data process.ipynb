# %%
import numpy as np
import pandas as pd
import os

import datetime

import fitz  # PyMuPDF
import re

# %% [markdown]
# ## LEIE

# %% [markdown]
# ### List of all exclusions and reinstatements starting in 2024

# %%
path_OIG = "OIG_exclude_csv/raw"

# %%
df_excl = pd.DataFrame()
df_rein = pd.DataFrame()
for filename in os.listdir(path_OIG):
    df1 = pd.read_csv(os.path.join(path_OIG, filename))
    df1['Y&M'] = filename[:4]
    if filename[-8:-4].lower() == "rein":
        if df_rein.empty:
            df_rein = df1
        else:
            df_rein = pd.concat([df_rein, df1], ignore_index=True)
    elif filename[-8:-4].lower() == "excl":
        if df_excl.empty:
            df_excl = df1
        else:
            df_excl = pd.concat([df_excl, df1], ignore_index=True)

# %%
True in df_rein.duplicated(subset = df_rein.columns[:6])
# Out:
# False

# %%
True in df_excl.duplicated(subset = df_excl.columns[:6])
# Out:
# False

# %%
df_all = pd.merge(df_excl, df_rein, how='outer', on = df_excl.columns[:6].tolist(),
         suffixes=('_excl', '_rein'))

# %%
update_time = datetime.datetime.now().strftime("%Y-%m-%d")

# %%
df_all.to_csv("OIG_exclude_csv/OIG_all_{}.csv".format(update_time), index=False)
df_rein.to_csv("OIG_exclude_csv/OIG_rein_{}.csv".format(update_time), index=False)
df_excl.to_csv("OIG_exclude_csv/OIG_excl_{}.csv".format(update_time), index=False)

# %%
df_all.query("REINDATE_rein.isnull()")
# Out:
#            LASTNAME FIRSTNAME   MIDNAME                         BUSNAME  \
# 0             AAKER  DEBHANNA       NaN                             NaN
# 2       ABAD-SANTOS  CRISELDA   CALAYAN                             NaN
# 3            ABANDA     JACOB  ATAMBILI                             NaN
# 4             ABARE     RICKY      JOHN                             NaN
# 6     ABAZIED COGAR       JOY     GAYLE                             NaN
# ...             ...       ...       ...                             ...
# 4817            NaN       NaN       NaN  THE HEALING TREE WELLNESS CENT
# 4818            NaN       NaN       NaN       TRUE FAMILY SERVICES, INC
# 4820            NaN       NaN       NaN  UNITED MEMORIAL MEDICAL CENTER
# 4821            NaN       NaN       NaN                     VDA OC, LLC
# 4822            NaN       NaN       NaN                 VIZION ONE, INC
#
#                    GENERAL             SPECIALTY UPIN_excl      NPI_excl  \
# 0     EMPLOYEE - PRIVATE S    HOME HEALTH AGENCY       NaN  0.000000e+00
# 2       PHYSICIAN (MD, DO)            PSYCHIATRY       NaN  1.760462e+09
# 3     IND- LIC HC SERV PRO  NURSE PRACTITIONER (       NaN  0.000000e+00
# 4     IND- LIC HC SERV PRO             THERAPIST       NaN  0.000000e+00
# 6     IND- LIC HC SERV PRO     NURSE/NURSES AIDE       NaN  0.000000e+00
# ...                    ...                   ...       ...           ...
# 4817        OTHER BUSINESS  MENTAL/BEHAVIORAL HE       NaN  1.093162e+09
# 4818        OTHER BUSINESS  MENTAL/BEHAVIORAL HE       NaN  1.124308e+09
# 4820        OTHER BUSINESS              HOSPITAL       NaN  1.891741e+09
# 4821  GOVERNMENT CONTRACTO      OTHER CONTRACTOR       NaN  1.649610e+09
# 4822        OTHER BUSINESS    HOME HEALTH AGENCY       NaN  1.801233e+09
#
#         DOB_excl                    ADDRESS_excl  ... ADDRESS_rein CITY_rein  \
# 0     19820311.0                     2006 OAK ST  ...          NaN       NaN
# 2     19631220.0                  8506 N ADIR DR  ...          NaN       NaN
# 3     19771212.0          12014 OSAGE PARK DRIVE  ...          NaN       NaN
# 4     19920129.0  4010 BOLTON VALLEY ACCESS ROAD  ...          NaN       NaN
# 6     19670405.0                      101 DEE ST  ...          NaN       NaN
# ...          ...                             ...  ...          ...       ...
# 4817         NaN  4270 S DECATUR BOULEVARD, SUIT  ...          NaN       NaN
# 4818         NaN          914 EAST SAHARA AVENUE  ...          NaN       NaN
# 4820         NaN              510 W TIDWELL ROAD  ...          NaN       NaN
# 4821         NaN  C/O REGISTERED AGENT - COOLIDG  ...          NaN       NaN
# 4822         NaN        6161 BUSCH BLVD, STE 180  ...          NaN       NaN
#
#       STATE_rein ZIP_rein  EXCLTYPE_rein  EXCLDATE_rein  REINDATE_rein  \
# 0            NaN      NaN            NaN            NaN            NaN
# 2            NaN      NaN            NaN            NaN            NaN
# 3            NaN      NaN            NaN            NaN            NaN
# 4            NaN      NaN            NaN            NaN            NaN
# 6            NaN      NaN            NaN            NaN            NaN
# ...          ...      ...            ...            ...            ...
# 4817         NaN      NaN            NaN            NaN            NaN
# 4818         NaN      NaN            NaN            NaN            NaN
# 4820         NaN      NaN            NaN            NaN            NaN
# 4821         NaN      NaN            NaN            NaN            NaN
# 4822         NaN      NaN            NaN            NaN            NaN
#
#       WAIVERDATE_rein WVRSTATE_rein Y&M_rein
# 0                 NaN           NaN      NaN
# 2                 NaN           NaN      NaN
# 3                 NaN           NaN      NaN
# 4                 NaN           NaN      NaN
# 6                 NaN           NaN      NaN
# ...               ...           ...      ...
# 4817              NaN           NaN      NaN
# 4818              NaN           NaN      NaN
# 4820              NaN           NaN      NaN
# 4821              NaN           NaN      NaN
# 4822              NaN           NaN      NaN
#
# [3980 rows x 32 columns]

# %% [markdown]
# ### leie_updated_information.pdf

# %%
pdf_path = "LEIE downloadable/2025-05-09/" 

file_name_update =  "leie_updated_information.pdf"
doc = fitz.open(pdf_path+file_name_update)

# %%
month_list = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

header_pos = {
    "LASTNAME": 2,
    "FIRSTNAME": 4,
    "MIDNAME": 6,
    "BUSNAME": 8,
    "GENERAL": 10,
    "SPECIALTY": 12,
    "UPIN": 14,
    "NPI": 16,
    "DOB": 18,
    "ADDRESS": 20,
    "CITY": 22,
    "STATE": 24,
    "ZIP": 26,
    "EXCLTYPE": 28,
    "EXCLDATE": 30
}

rename_dict = {
    0: "Update month",
    1: "Update",
    3: "LASTNAME",
    5: "FIRSTNAME",
    7: "MIDNAME",
    9: "BUSNAME",
    11: "GENERAL",
    13: "SPECIALTY",
    15: "UPIN",
    17: "NPI",
    19: "DOB",
    21: "ADDRESS",
    23: "CITY",
    25: "STATE",
    27: "ZIP",
    29: "EXCLTYPE",
    31: "EXCLDATE"   
}

# %%
pages = []
pages_abnormal = []
num_abnormal = []
time_update = ''

for num,page in enumerate(doc):
    text = page.get_text()
    lines = [line.strip() for line in text.split('\n')]
    if lines[0] == "Updated LEIE Information":
        lines = lines[1:]

    if lines[0] == "":
        lines = lines[1:]

    if lines[0][:3] in month_list:
        time_update = lines[0]
    else:
        lines.insert(0, time_update)

    for i in header_pos.keys():
        index = lines.index(i)      
        if index < header_pos[i]:  
            lines.insert(index, "")
        elif index > header_pos[i]:
            lines_before = lines[:header_pos[i]-1]
            lines_after = lines[index:]
            lines_between = [" ".join(lines[header_pos[i]-1:index])]
            if isinstance(lines_before, str):
                lines_before = [lines_before]
            lines = lines_before + lines_between + lines_after

    # print(lines)

    if len(lines) > 34:
        pages_abnormal.append(lines)
        num_abnormal.append(num)
    else:
        pages.append(lines)

# %% [markdown]
# #### most of the pages can be tranformed by the codes above

# %%
df_raw = pd.DataFrame(pages)
df_raw.rename(columns=rename_dict, inplace=True)
df_raw = df_raw[rename_dict.values()]
df_raw['Update'] = df_raw['Update'].str.replace("Update:","")

# %%
df_raw
# Out:
#       Update month                              Update     LASTNAME FIRSTNAME  \
# 0       April 2025   Subject Sub-Type and Subject Type
# 1       April 2025   Subject Type and Subject Sub-Type
# 2       April 2025   Subject Type and Subject Sub-Type
# 3       April 2025   Subject Type and Subject Sub-Type
# 4       April 2025   Subject Sub-Type and Subject Type
# ..             ...                                 ...          ...       ...
# 112     March 2025                       Date of Birth  PEREZ OYOLA     MAYRA
# 113     March 2025                       Date of Birth       TAYLOR     NANCY
# 114  February 2025                                 SSN       BOLDEN     DANTE
# 115  February 2025                       Date of Birth      HEMBREE    LENORA
# 116  February 2025                       Date of Birth           HO   RICHARD
#
#       MIDNAME                       BUSNAME               GENERAL  \
# 0               BELL LAB AND X-RAY SERVICES        OTHER BUSINESS
# 1                        COALFIELD PHARMACY        OTHER BUSINESS
# 2                           HINTON PHARMACY        OTHER BUSINESS
# 3              JOHN'S MINI-BUS SERVICE, INC        OTHER BUSINESS
# 4              RONALD W HIGGINS, D D S, P C        OTHER BUSINESS
# ..        ...                           ...                   ...
# 112     ELENA                                      BUS OWNER/EXEC
# 113  LOCKWOOD                                IND- LIC HC SERV PRO
# 114         L                                EMPLOYEE - PRIVATE S
# 115      JEAN                                  NURSING PROFESSION
# 116   KAY-YIN                                MEDICAL PRACTICE, MD
#
#                SPECIALTY    UPIN         NPI       DOB  \
# 0             LABORATORY          0000000000
# 1               PHARMACY          0000000000
# 2               PHARMACY          0000000000
# 3      TRANSPORTATION CO          0000000000
# 4        DENTAL PRACTICE          0000000000
# ..                   ...     ...         ...       ...
# 112       RENAL FACILITY          0000000000  19530909
# 113    NURSE/NURSES AIDE          0000000000  19530915
# 114  SKILLED NURSING FAC          0000000000  19920127
# 115    NURSE/NURSES AIDE          0000000000  19671001
# 116  GENERAL PRACTICE/FP  A47499  0000000000  19491224
#
#                           ADDRESS        CITY STATE        ZIP EXCLTYPE  \
# 0    17442 VIRGINIA AVENUE, APT 2  BELLFLOWER    CA  907060000   1128a1
# 1        109 HICKORY HOLLOW DRIVE   OAK RIDGE    TN  378300000   1128a1
# 2       C/O 1447 COUNTY FARM ROAD     RAYMOND    MS  391540000   1128b8
# 3           148-14 LIBERTY AVENUE     JAMAICA    NY  114350000   1128a1
# 4          3400 SQUALICUM PARKWAY  BELLINGHAM    WA  982250000   1128a1
# ..                            ...         ...   ...        ...      ...
# 112                    A1 CALLE 1    SAN JUAN    PR  009240000   1128a2
# 113         2509 LOCH HAVEN DRIVE       PLANO    TX  750235316   1128b4
# 114     827 N MADISON ST, # 19801  WILMINGTON    DE  198011437   1128a2
# 115     1728 102ND STREET, UNIT B     LUBBOCK    TX  794230000   1128b4
# 116      4043 HASTINGS PARK COURT    SAN JOSE    CA  951360000   1128b4
#
#      EXCLDATE
# 0    19870724
# 1    19880624
# 2    19950216
# 3    19870302
# 4    19881228
# ..        ...
# 112  20250320
# 113  20160720
# 114  20240118
# 115  19890623
# 116  19971007
#
# [117 rows x 17 columns]

# %% [markdown]
# #### Manual input of a PDF that cannot be deconstructed properly

# %%
pd.DataFrame(pages_abnormal).to_csv("LEIE downloadable/abnormal_pages.csv", index=False)

# %%
df_changed = pd.read_csv("LEIE downloadable/changed_abnormal_pages.csv")
df_raw = pd.concat([df_raw, df_changed], ignore_index=True)

# %% [markdown]
# #### store as csv

# %%
df_raw.to_csv(pdf_path + file_name_update[:-4] + ".csv", index=False)

# %% [markdown]
# ### leie_record_layout

# %%
file_name_layout =  "leie_record_layout.pdf"
doc_layout = fitz.open(pdf_path+file_name_layout)

# %%
for num,page in enumerate(doc_layout):
    text = page.get_text()
    lines = [line.strip() for line in text.split('\n')]
    lines = [line for line in lines if line != ""]
    pd.DataFrame({lines[0]: lines[2::2], lines[1]: lines[3::2]}).to_csv(pdf_path + file_name_layout[:-4] + ".csv", index=False)

# %% [markdown]
# ## Georgia OIG

# %%
xls = pd.ExcelFile("GA OIG exclude/dch-oig-exclusions-list-05062025.xlsx")

all_sheets = {}
for sheet_name in xls.sheet_names:
    df = xls.parse(sheet_name)
    if df.empty:
        continue
    all_sheets[sheet_name] = df

# %%
all_sheets.keys()
# Out:
# dict_keys(['Sheet1'])

# %%
df = pd.read_excel("GA OIG exclude/dch-oig-exclusions-list-05062025.xlsx", sheet_name="Sheet1",skiprows=2)

# %%
df.to_csv("GA OIG exclude/dch-oig-exclusions-list-05062025.csv", index=False)
